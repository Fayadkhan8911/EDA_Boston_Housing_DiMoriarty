# %% [markdown]
# <!--Collapsible Headings-->
#   ## EDA of Boston Housing By DiMoriarty
#
# Goal of this EDA
# - maximize insight into a data set
# - uncover underlying structure
# - extract important variables
# - detect outliers and anomalies
# - test underlying assumptions
# - determine optimal factor settings
#
# Legends
# - CRIM     per capita crime rate by town
# - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS    proportion of non-retail business acres per town
# - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# - NOX      nitric oxides concentration (parts per 10 million)
# - RM       average number of rooms per dwelling
# - AGE      proportion of owner-occupied units built prior to 1940
# - DIS      weighted distances to five Boston employment centres
# - RAD      index of accessibility to radial highways
# - TAX      full-value property-tax rate per $10,000
# - PTRATIO  pupil-teacher ratio by town
# - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# - LSTAT    % lower status of the population

# %%
import pandas as pd
import numpy as np
from numpy.random import randn, randint, uniform, sample
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from numpy.random import randn, randint, uniform, sample
from pandas.plotting import scatter_matrix
pd.set_option('display.max_rows', 20)
fig=plt.figure()
import plotly as py
from plotly.offline import iplot
import cufflinks as cf
#cmap = plt.get_cmap('tab20c')

# %% [markdown]
# <!--Collapsible Headings-->
# ## Preparing the data

# %%
import pickle as pkl

# %%
_boston = pkl.load(open('boston_housing.pkl', 'rb'))

# %%
type(_boston)
# Out:
# sklearn.utils._bunch.Bunch

# %%
_boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
print(_boston.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
print(_boston.filename)
# Out:
# C:\Users\Laxmi\AppData\Roaming\Python\Python37\site-packages\sklearn\datasets\data\boston_house_prices.csv

# %%
print(_boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
df=_boston.data

# %%
_df = pd.DataFrame(data = df, columns=_boston.feature_names)
_df.sample(10)
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 101   0.11432   0.0   8.56   0.0  0.520  6.781   71.3  2.8561   5.0  384.0
# 249   0.19073  22.0   5.86   0.0  0.431  6.718   17.5  7.8265   7.0  330.0
# 497   0.26838   0.0   9.69   0.0  0.585  5.794   70.6  2.8927   6.0  391.0
# 416  10.83420   0.0  18.10   0.0  0.679  6.782   90.8  1.8195  24.0  666.0
# 209   0.43571   0.0  10.59   1.0  0.489  5.344  100.0  3.8750   4.0  277.0
# 346   0.06162   0.0   4.39   0.0  0.442  5.898   52.3  8.0136   3.0  352.0
# 242   0.10290  30.0   4.93   0.0  0.428  6.358   52.9  7.0355   6.0  300.0
# 380  88.97620   0.0  18.10   0.0  0.671  6.968   91.9  1.4165  24.0  666.0
# 54    0.01360  75.0   4.00   0.0  0.410  5.888   47.6  7.3197   3.0  469.0
# 248   0.16439  22.0   5.86   0.0  0.431  6.433   49.1  7.8265   7.0  330.0
#
#      PTRATIO       B  LSTAT
# 101     20.9  395.58   7.67
# 249     19.1  393.74   6.56
# 497     19.2  396.90  14.10
# ...

# %%
_df['price']=_boston.target
_df.sample(5)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 499  0.17783   0.0   9.69   0.0  0.585  5.569   73.5  2.3999   6.0  391.0
# 8    0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 185  0.06047   0.0   2.46   0.0  0.488  6.153   68.8  3.2797   3.0  193.0
# 9    0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 441  9.72418   0.0  18.10   0.0  0.740  6.406   97.2  2.0651  24.0  666.0
#
#      PTRATIO       B  LSTAT  price
# 499     19.2  395.77  15.10   17.5
# 8       15.2  386.63  29.93   16.5
# 185     17.8  387.11  13.15   29.6
# 9       15.2  386.71  17.10   18.9
# 441     20.2  385.96  19.52   17.1

# %%
_df.shape
# Out:
# (506, 14)

# %% [markdown]
# <!--Collapsible Headings-->
# ## Brief details

# %%
_desc=_df.describe()
_desc
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
_desc.loc[['mean']]
# Out:
#           CRIM         ZN      INDUS     CHAS       NOX        RM        AGE  \
# mean  3.613524  11.363636  11.136779  0.06917  0.554695  6.284634  68.574901
#
#            DIS       RAD         TAX    PTRATIO           B      LSTAT  \
# mean  3.795043  9.549407  408.237154  18.455534  356.674032  12.653063
#
#           price
# mean  22.532806

# %%
_df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  price    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
_df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# price      0
# dtype: int64

# %%
_df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# price      0
# dtype: int64

# %%
_df.duplicated().sum()
# Out:
# 0

# %%
fig, ax = plt.subplots(4, 2, figsize = (15,10 ),dpi=90)

ax[0,0].plot(_desc.loc['mean'],c='red')
ax[0,0].set_title('Mean')
ax[0,1].plot(_desc.loc['std'],c='blue')
ax[0,1].set_title('STD')
ax[1,0].plot(_desc.loc['count'],c='green')
ax[1,0].set_title('Count')
ax[1,1].plot(_desc.loc['max'],c='purple')
ax[1,1].set_title('Max')
ax[2,0].plot(_desc.loc['min'],c='maroon')
ax[2,0].set_title('Min')
ax[2,1].plot(_desc.loc['25%'],c='navy')
ax[2,1].set_title('25%')
ax[3,0].plot(_desc.loc['50%'],c='orange')
ax[3,0].set_title('50%')
ax[3,1].plot(_desc.loc['75%'],c='brown')
ax[3,1].set_title('75%')


plt.tight_layout()

# %% [markdown]
# <!--Collapsible Headings-->
# ## Plots Styles

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
len(plt.style.available)
# Out:
# 28

# %%
style='seaborn-v0_8'
plt.style.use(style)
_desc.loc['mean'].plot(figsize=(6,4))

plt.title(style)
# Out:
# Text(0.5, 1.0, 'seaborn-v0_8')

# %% [markdown]
# <!--Collapsible Headings-->
# ## Pair plots

# %%
_df.sample(10)
# Out:
#         CRIM     ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 219  0.11425    0.0  13.89   1.0  0.550  6.373  92.4  3.3633  5.0  276.0
# 220  0.35809    0.0   6.20   1.0  0.507  6.951  88.5  2.8617  8.0  307.0
# 116  0.13158    0.0  10.01   0.0  0.547  6.176  72.5  2.7301  6.0  432.0
# 307  0.04932   33.0   2.18   0.0  0.472  6.849  70.3  3.1827  7.0  222.0
# 244  0.20608   22.0   5.86   0.0  0.431  5.593  76.5  7.9549  7.0  330.0
# 57   0.01432  100.0   1.32   0.0  0.411  6.816  40.5  8.3248  5.0  256.0
# 201  0.03445   82.5   2.03   0.0  0.415  6.162  38.4  6.2700  2.0  348.0
# 32   1.38799    0.0   8.14   0.0  0.538  5.950  82.0  3.9900  4.0  307.0
# 497  0.26838    0.0   9.69   0.0  0.585  5.794  70.6  2.8927  6.0  391.0
# 75   0.09512    0.0  12.83   0.0  0.437  6.286  45.0  4.5026  5.0  398.0
#
#      PTRATIO       B  LSTAT  price
# 219     16.4  393.74  10.50   23.0
# 220     17.4  391.70   9.71   26.7
# 116     17.8  393.30  12.04   21.2
# ...

# %%
plt.style.use('dark_background')
sns.pairplot(_df.iloc[:, np.hstack(([0], range(1, 7)))], diag_kind='kde')

# %%
plt.style.use('dark_background')
sns.pairplot(_df.iloc[:, np.hstack(([0], range(7, 13)))], diag_kind='kde')

# %% [markdown]
# <!--Collapsible Headings-->
# ## Distribution Plot

# %%
_row=2
_col=7
col=_df.columns
index=0
plt.style.use('dark_background')
fig,ax=plt.subplots(ncols=_col,nrows=_row,figsize=(16,4))
for _r in range(_row):
    for _c in range(_col):
        sns.histplot(_df[col[index]],ax=ax[_r][_c],kde=True,color='red')
        index=index+1
plt.tight_layout()
plt.show()

# %% [markdown]
# <!--Collapsible Headings-->
# ## Price vs remainning plots
#
# Scatter plots

# %%
_R=2
_C=7
_col=_df.columns
index=0
fig,ax=plt.subplots(nrows=_R,ncols=_C,figsize=(16,4))
for R in range(_R):
    for C in range(_C):
        sns.scatterplot(x='price',y=_col[index],data=_df,color='red',ax=ax[R][C])
        index=index+1
plt.tight_layout()
plt.show()

# %% [markdown]
# <!--Collapsible Headings-->
# ## Heatmap

# %%
_cor=_df.corr()
_cor
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
sns.heatmap(data=_cor,cmap='magma',annot=True,cbar=True)
# Out:
# <Axes: >

# %% [markdown]
# <!--Collapsible Headings-->
# ## Correlated features

# %%
_cor.index
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'price'],
#       dtype='object')

# %%
def cus_corr_feat(_cor_data,_threshold):
    _fields=[]
    _values=[]
    
    for i,index in enumerate(_cor_data.index):
        if abs(_cor_data[index])>_threshold:
            _fields.append(index)
            _values.append(_cor_data[index])
    _df_corr=pd.DataFrame(data=_values,index=_fields,columns=['corr_values'])
    return _df_corr

# %%
_thres=.5
_df_corr_price=cus_corr_feat(_cor['price'],_thres)

# %%
_df_corr_price
# Out:
#          corr_values
# RM          0.695360
# PTRATIO    -0.507787
# LSTAT      -0.737663
# price       1.000000

# %% [markdown]
# <!--Collapsible Headings-->
# ## Heatmap and Pairplot with Correlated features

# %%
_cor_data_price=_df[_df_corr_price.index]
_cor_data_price.head()
# Out:
#       RM  PTRATIO  LSTAT  price
# 0  6.575     15.3   4.98   24.0
# 1  6.421     17.8   9.14   21.6
# 2  7.185     17.8   4.03   34.7
# 3  6.998     18.7   2.94   33.4
# 4  7.147     18.7   5.33   36.2

# %%
sns.heatmap(data=_cor_data_price.corr(),annot=True,cmap='magma',cbar=True)
# Out:
# <Axes: >

# %%
plt.style.use('ggplot')
sns.pairplot(_cor_data_price,height=2)
plt.tight_layout()

# %% [markdown]
# <!--Collapsible Headings-->
# ## Boxplots and Relplots

# %% [markdown]
# Legends
# - CRIM     per capita crime rate by town
# - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS    proportion of non-retail business acres per town
# - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# - NOX      nitric oxides concentration (parts per 10 million)
# - RM       average number of rooms per dwelling
# - AGE      proportion of owner-occupied units built prior to 1940
# - DIS      weighted distances to five Boston employment centres
# - RAD      index of accessibility to radial highways
# - TAX      full-value property-tax rate per $10,000
# - PTRATIO  pupil-teacher ratio by town
# - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# - LSTAT    % lower status of the population

# %%
_df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'price'],
#       dtype='object')

# %%
plt.figure(dpi=70)
plt.style.use('ggplot')
sns.boxplot(data=_df,x='CHAS',y='price')
# Out:
# <Axes: xlabel='CHAS', ylabel='price'>

# %%
sns.relplot(data=_df,x='RM',y='price',hue='CHAS')

# %%
sns.relplot(data=_df,x='RM',y='price',col='CHAS',height=4,aspect=2)

# %% [markdown]
# <!--Collapsible Headings-->
# ## Joint plots

# %%
sns.jointplot(data=_df,x='price',y='RM')

# %% [markdown]
# <!--Collapsible Headings-->
# ## Linear regression and relations

# %%
_df.sample(5)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 390  6.96215   0.0  18.10   0.0  0.700  5.713   97.0  1.9265  24.0  666.0
# 443  9.96654   0.0  18.10   0.0  0.740  6.485  100.0  1.9784  24.0  666.0
# 146  2.15505   0.0  19.58   0.0  0.871  5.628  100.0  1.5166   5.0  403.0
# 342  0.02498   0.0   1.89   0.0  0.518  6.540   59.7  6.2669   1.0  422.0
# 341  0.01301  35.0   1.52   0.0  0.442  7.241   49.3  7.0379   1.0  284.0
#
#      PTRATIO       B  LSTAT  price
# 390     20.2  394.43  17.11   15.1
# 443     20.2  386.73  18.85   15.4
# 146     14.7  169.27  16.65   15.6
# 342     15.9  389.96   8.65   16.5
# 341     15.5  394.74   5.49   32.7

# %%
plt.figure(dpi=70)
sns.regplot(data=_df,y='price',x='RM',robust=True)
# Out:
# <Axes: xlabel='RM', ylabel='price'>

# %%
plt.figure(dpi=50)
sns.lmplot(data=_df,y='price',x='RM',robust=True,height=4,aspect=2)

# %%
plt.figure(dpi=70)
sns.lmplot(data=_df,y='price',x='RM',robust=True,col='CHAS',height=4,aspect=1)

# %%
sns.lmplot(x = 'RM', y = 'price', data = _df, col = 'CHAS', order = 2,height=5)

# %%
sns.lmplot(x = 'CHAS', y = 'price', data = _df, x_estimator=np.mean)
